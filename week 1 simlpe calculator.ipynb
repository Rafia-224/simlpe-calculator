# %%
# %%markdown
# # **WEEK 1 SIMPLE CALCULATOR**
# Out:
# # **WEEK 1 SIMPLE CALCULATOR**

# %%
# %%markdown
# # **THIS NOTEBOOK TAKES TWO AND PERFORM ADD, SUB,MULTI and DIV**
# Out:
# # **THIS NOTEBOOK TAKES TWO AND PERFORM ADD, SUB,MULTI and DIV**

# %%
num1=float(input("enter first number"))
num2=float(input("enter your second number (not zero)"))

ADD=num1+num2
print("addition:", ADD)
SUB=num1+num2
print("subtraction:" , SUB)
MULTI=num1+num2
print("multiplication:" , MULTI)
DIV=num1+num2
print("division:" , DIV)
# Out:
# enter first number 2
# enter your second number (not zero) 4
# addition: 6.0
# subtraction: 6.0
# multiplication: 6.0
# division: 6.0
